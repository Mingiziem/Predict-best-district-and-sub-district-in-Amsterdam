# %% [markdown]
# <h2>Week ****   2. Project on Amsterdam</h2>

# %% [markdown]
# # * How to Pick and Move to the Best Neighborhood?

# %% [markdown]
# <li>Ask the Right Questions?
#          variables

# %% [markdown]
# <p> Remember: if you are planing on purchasing a home, you are not just buying a house, you  are investing in a neighborhod</p>

# %% [markdown]
# <img src="districts.jpg">

# %% [markdown]
# <img src="ams.jpg">

# %% [markdown]
# <ul>
#     <li>Data Cleaning</li>
#     <li>Dataframe using pandas </li>
#     <li>Exporting and Importing </li>
#     <li>Python Function </li>
#     <li>MySql Queries </li>
#     <li>Apply and Mapping function</li>
#     <li>Grouping and selection </li>
#     <li>*** Loc and iloc </li>
#     <li>*** importing libraries </li>
#     <li>***New*** Indexing Multiple index </li>
#     <li>***New*** Rank function and rank methods</li>
#     <li>***Using different formats of jupter</li>
#     <li>***Dataframe Formats ***</li>
#   </ul>

# %% [markdown]
# # About Week 2. Project

# %% [markdown]
# <img src="2.png"/>

# %% [markdown]
# <img src="1.png"/>

# %% [markdown]
# <img src="3.png"/>

# %% [markdown]
# <img src="4.png"/>

# %%
#import necessary liberaries 
import pandas as pd
import numpy as np
import re
import sqlalchemy
from sqlalchemy import create_engine
import math
import random
import xlrd

# %%
#Accessing the final clean data from csv file 
amsterdam_data='AmsterDATA.xlsx'
AmsterData= pd.read_excel(amsterdam_data)
AmsterData.style.set_properties(**{'background-color':'teal',
                                   'color':'yellow',
                                   'boarder-color':'black',
                                   'boarder-width':'1px',
                                   'border-style':'solid'})
#AmsterData.to_excel("AmsterDATA.xlsx", index=False)
# Out:
# <style  type="text/css" >
#     #T_efdc60dc_9ffd_11ea_9748_2c337a42c77arow0_col0 {
#             background-color:  teal;
#             color:  yellow;
#             boarder-color:  black;
#             boarder-width:  1px;
#             border-style:  solid;
#         }    #T_efdc60dc_9ffd_11ea_9748_2c337a42c77arow0_col1 {
#             background-color:  teal;
#             color:  yellow;
#             boarder-color:  black;
#             boarder-width:  1px;
#             border-style:  solid;
#         }    #T_efdc60dc_9ffd_11ea_9748_2c337a42c77arow0_col2 {
#             background-color:  teal;
#             color:  yellow;
#             boarder-color:  black;
#             boarder-width:  1px;
#             border-style:  solid;
#         }    #T_efdc60dc_9ffd_11ea_9748_2c337a42c77arow0_col3 {
#             background-color:  teal;
#             color:  yellow;
#             boarder-color:  black;
#             boarder-width:  1px;
#             border-style:  solid;
# ...

# %%
#Describe the objects 
AmsterData.describe(include="object").style.set_properties(**{'background-color':'grey',
                                   'color':'Yellow',
                                   'boarder-color':'black',
                                   'boarder-width':'1px',
                                   'border-style':'solid'})
# Out:
# <style  type="text/css" >
#     #T_f03ef45c_9ffd_11ea_97cd_2c337a42c77arow0_col0 {
#             background-color:  grey;
#             color:  Yellow;
#             boarder-color:  black;
#             boarder-width:  1px;
#             border-style:  solid;
#         }    #T_f03ef45c_9ffd_11ea_97cd_2c337a42c77arow0_col1 {
#             background-color:  grey;
#             color:  Yellow;
#             boarder-color:  black;
#             boarder-width:  1px;
#             border-style:  solid;
#         }    #T_f03ef45c_9ffd_11ea_97cd_2c337a42c77arow1_col0 {
#             background-color:  grey;
#             color:  Yellow;
#             boarder-color:  black;
#             boarder-width:  1px;
#             border-style:  solid;
#         }    #T_f03ef45c_9ffd_11ea_97cd_2c337a42c77arow1_col1 {
#             background-color:  grey;
#             color:  Yellow;
#             boarder-color:  black;
#             boarder-width:  1px;
#             border-style:  solid;
# ...

# %%
Ranking_range=[]
for rank in AmsterData.avg_rent:
    if rank<=500:
        Ranking_range.append("Maximum")
    else:
        Ranking_range.append("Minimum")

# %%
#Ranking_range[0:7]

# %%
Rank_District=AmsterData.groupby(['Region','Average_Rent']).boxplot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-b109b8565195> in <module>
# ----> 1 Rank_District=AmsterData.groupby(['Region','Average_Rent']).boxplot()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed)
#    5808             group_keys=group_keys,
#    5809             squeeze=squeeze,
# -> 5810             observed=observed,
#    5811         )
#    5812
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated)
#     407                 sort=sort,
#     408                 observed=observed,
# --> 409                 mutated=self.mutated,
#     410             )
#     411
#
# ...

# %%
#Multiple indexing the region with sub regions since we have 129 values with unique 7
AmsterData.set_index(['region'],inplace=False)
AmsterData.sort_index(inplace=True)
AmsterData.head(2).style.set_properties(**{'background-color':'grey',
                                   'color':'Yellow',
                                   'boarder-color':'black',
                                   'boarder-width':'1px',
                                   'border-style':'solid'})
# Out:
# <style  type="text/css" >
#     #T_f11558ee_9ffd_11ea_a493_2c337a42c77arow0_col0 {
#             background-color:  grey;
#             color:  Yellow;
#             boarder-color:  black;
#             boarder-width:  1px;
#             border-style:  solid;
#         }    #T_f11558ee_9ffd_11ea_a493_2c337a42c77arow0_col1 {
#             background-color:  grey;
#             color:  Yellow;
#             boarder-color:  black;
#             boarder-width:  1px;
#             border-style:  solid;
#         }    #T_f11558ee_9ffd_11ea_a493_2c337a42c77arow0_col2 {
#             background-color:  grey;
#             color:  Yellow;
#             boarder-color:  black;
#             boarder-width:  1px;
#             border-style:  solid;
#         }    #T_f11558ee_9ffd_11ea_a493_2c337a42c77arow0_col3 {
#             background-color:  grey;
#             color:  Yellow;
#             boarder-color:  black;
#             boarder-width:  1px;
#             border-style:  solid;
# ...

# %%
def rankingSubregion():
### This is the report for each variable in the sub region ranking and choosing 
    print("Select here:")
    print("Press 1. For detail rent *Press 2. For Population Density ** Press3. Sport and Cultural facilities\n")
    print("press 4. parking facilities ** Press 5. Nuisance crime   *Press 6.For Care Facilities  ")
    num=input("Which variable you want to see detail Ranking?")
    print("                           XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX                                  ")
    print("                          XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX                                  ")
    print("XXXXXXXXXXXXXXXXXXXXXXXX           GEMENTE AMSTERDAM             XXXXXXXXXXXXXXXXxxXXXXXXXX")
    print("XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX      Report             XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
    print(" ..........................XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX.................................")
    print("                           XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX                                  ")
    num2=input("Whic destrict you want to see detail?\n 1. Centrum 2. West 3. noordt  4. zuid 5.N_west 6. Zuidoost 7.Oost")
    print("                             XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX                                  ")


    if num=='1':
        print("Overall and Sub region Ranking in every varialb\n")
        Rank_catagory=AmsterData.groupby(['region','avg_rent','Location']).avg_rent.agg(['mean']).reset_index()
        Rank_catagory['Rent_Rank']=Rank_catagory.groupby('region')['avg_rent'].rank(ascending=False,method='dense')   
        if num2=='1':  
            print(Rank_catagory.loc[0:12, :])
            y=Rank_catagory.loc[0:12, :]        
            print("This is the centrum region with sub districts:\n",y.plot(kind='bar'))
        elif num2=='2':  
            print(Rank_catagory.plot(kind='bar'))
            print("This is the west region with sub districts:\n",Rank_catagory.loc[72:94, :])
        elif num2=='3':        
            print("This is the Noord region\n", Rank_catagory.loc[34:49, :])
        elif num2=='4':        
            print("This is the zuid region\n", Rank_catagory.loc[95:117, :])
        elif num2=='5':        
            print("This is the new west region\n", Rank_catagory.loc[13:33, :])
        elif num2=='6':        
            print("This is the zuidoost region\n", Rank_catagory.loc[118:, :])
        else:        
            print("This is the oost region\n", Rank_catagory.loc[50:71, :])     
    elif num=='2':
        print("Population density every region")
        Rank_catagory=AmsterData.groupby(['region','population_density','Location']).population_density.agg(['mean']).reset_index()
        Rank_catagory['Population_D_Rank']=Rank_catagory.groupby('region')['population_density'].rank(ascending=False,method='dense')
        if num2=='1':        
            print("This is the centrum region with sub districts:\n",Rank_catagory.loc[0:12, :])
        elif num2=='2':         
            print("This is the west region with sub districts:\n",Rank_catagory.loc[72:94, :])
        elif num2=='3':         
            print("This is the Noord region\n", Rank_catagory.loc[34:49, :])
        elif num2=='4':         
            print("This is the zuid region\n", Rank_catagory.loc[95:117, :])
        elif num2=='5':         
            print("This is the new west region\n", Rank_catagory.loc[13:33, :])
        elif num2=='6':         
            print("This is the zuidoost region\n", Rank_catagory.loc[118:, :])
        else:         
            print("This is the oost region\n", Rank_catagory.loc[50:71, :])
    elif num=='3':
        print("Sport and cultural facilities in each sub region of Amsterdam:")
        Rank_catagory=AmsterData.groupby(['region','sport_cultural','Location']).sport_cultural.agg(['mean']).reset_index()     
        Rank_catagory['Sport_cultur_Rank']=Rank_catagory.groupby('region')['sport_cultural'].rank(ascending=False,method='dense')
        if num2=='1':        
            print("This is the centrum region with sub districts:\n",Rank_catagory.loc[0:12, :])
        elif num2=='2':         
            print("This is the west region with sub districts:\n",Rank_catagory.loc[72:94, :])
        elif num2=='3':         
            print("This is the Noord region\n", Rank_catagory.loc[34:49, :])
        elif num2=='4':         
            print("This is the zuid region\n", Rank_catagory.loc[95:117, :])
        elif num2=='5':         
            print("This is the new west region\n", Rank_catagory.loc[13:33, :])
        elif num2=='6':         
            print("This is the zuidoost region\n", Rank_catagory.loc[118:, :])
        else:         
            print("This is the oost region\n", Rank_catagory.loc[50:71, :])    
    elif num=='4':
        print("Parking facilities in each sub region of Amserdam")
        Rank_catagory=AmsterData.groupby(['region','parking','Location']).parking.agg(['mean']).reset_index()     
        Rank_catagory['Parking_Rank']=Rank_catagory.groupby('region')['parking'].rank(ascending=False,method='dense')
        if num2=='1':        
            print("This is the centrum region with sub districts:\n",Rank_catagory.loc[0:12, :])
        elif num2=='2':         
            print("This is the west region with sub districts:\n",Rank_catagory.loc[72:94, :])
        elif num2=='3':         
            print("This is the Noord region\n", Rank_catagory.loc[34:49, :])
        elif num2=='4':        
            print("This is the zuid region\n", Rank_catagory.loc[95:117, :])
        elif num2=='5':        
            print("This is the new west region\n", Rank_catagory.loc[13:33, :])
        elif num2=='6':         
            print("This is the zuidoost region\n", Rank_catagory.loc[118:, :])
        else:        
            print("This is the oost region\n", Rank_catagory.loc[50:71, :])    
    elif num=='5':
        print('Nuisance Crime and Nuisance hospitalitiy in each sub region of Amsterdam')
        Rank_catagory=AmsterData.groupby(['region','nuisance_crime_hospitality','Location']).nuisance_crime_hospitality.agg(['mean']).reset_index()
        Rank_catagory['Crime_Rank']=Rank_catagory.groupby('region')['nuisance_crime_hospitality'].rank(ascending=False,method='dense')
        if num2=='1':        
            print("This is the centrum region with sub districts:\n",Rank_catagory.loc[0:12, :])
        elif num2=='2':         
            print("This is the west region with sub districts:\n",Rank_catagory.loc[72:94, :])
        elif num2=='3':         
            print("This is the Noord region\n", Rank_catagory.loc[34:49, :])
        elif num2=='4':         
            print("This is the zuid region\n", Rank_catagory.loc[95:117, :])
        elif num2=='5':        
            print("This is the new west region\n", Rank_catagory.loc[13:33, :])
        elif num2=='6':         
            print("This is the zuidoost region\n", Rank_catagory.loc[118:, :])
        else:         
            print("This is the oost region\n", Rank_catagory.loc[50:71, :])
    else: 
        print('Care facilities in each region of the Amsterdam')
        Rank_catagory=AmsterData.groupby(['region','care_facilities','Location']).care_facilities.agg(['mean']).reset_index()
        Rank_catagory['care_facilities_Rank']=Rank_catagory.groupby('region')['avg_rent'].rank(ascending=False,method='dense')
        if num2=='1':        
            print("This is the centrum region with sub districts:\n",Rank_catagory.loc[0:12, :])
        elif num2=='2':         
            print("This is the west region with sub districts:\n",Rank_catagory.loc[72:94, :])
        elif num2=='3':        
            print("This is the Noord region\n", Rank_catagory.loc[34:49, :])
        elif num2=='4':         
            print("This is the zuid region\n", Rank_catagory.loc[95:117, :])
        elif num2=='5':         
            print("This is the new west region\n", Rank_catagory.loc[13:33, :])
        elif num2=='6':         
            print("This is the zuidoost region\n", Rank_catagory.loc[118:, :])
        else:         
            print("This is the oost region\n", Rank_catagory.loc[50:71, :])

# %%
driver = 'mysql+pymysql:'
user = 'root'
password = 'xxxxxxxx'
ip = '127.0.0.1'
database = 'amsterdata'
connection_string = f'{driver}//{user}:{password}@{ip}/{database}'
engine = create_engine(connection_string)
#AmsterDATA=AmsterData.to_sql('main_data', engine, index=False)

#This is the exporting to sql the cleand data

# %%
driver = 'mysql+pymysql:'
user = 'root'
password = 'Mingii1212@'
ip = '127.0.0.1'
database = 'AmsterData'
connection_string = f'{driver}//{user}:{password}@{ip}/{database}'
engine = create_engine(connection_string, pool_size=10, max_overflow=20)
query = """
        SELECT region As Region,AVG(avg_rent) AS Average_Rent,AVG(population_density) As population_density,AVG(parking) As Parking,AVG(entrepreneurs) As Enterpreneurs,AVG(safe_day_night) As safe_day_night,AVG(sport_cultural) As sport_cultural,
        AVG(nuisance_crime_hospitality) As nuisance_crime,AVG(group_interaction) As group_interaction,AVG(care_facilities) As care_facilities from main_data
        where region='centrum';
        
         """
dfcentrum = pd.read_sql(query, engine)
dfcentrum.style.set_properties(**{'background-color':'grey',
                                   'color':'Yellow',
                                   'boarder-color':'black',
                                   'boarder-width':'1px',
                                   'border-style':'solid'})
# Out:
# <style  type="text/css" >
#     #T_f2e0a78a_9ffd_11ea_b223_2c337a42c77arow0_col0 {
#             background-color:  grey;
#             color:  Yellow;
#             boarder-color:  black;
#             boarder-width:  1px;
#             border-style:  solid;
#         }    #T_f2e0a78a_9ffd_11ea_b223_2c337a42c77arow0_col1 {
#             background-color:  grey;
#             color:  Yellow;
#             boarder-color:  black;
#             boarder-width:  1px;
#             border-style:  solid;
#         }    #T_f2e0a78a_9ffd_11ea_b223_2c337a42c77arow0_col2 {
#             background-color:  grey;
#             color:  Yellow;
#             boarder-color:  black;
#             boarder-width:  1px;
#             border-style:  solid;
#         }    #T_f2e0a78a_9ffd_11ea_b223_2c337a42c77arow0_col3 {
#             background-color:  grey;
#             color:  Yellow;
#             boarder-color:  black;
#             boarder-width:  1px;
#             border-style:  solid;
# ...

# %%
query = """
        SELECT region As Region,AVG(avg_rent) AS Average_Rent,AVG(population_density) As population_density,AVG(parking) As Parking,AVG(entrepreneurs) As Enterpreneurs,AVG(safe_day_night) As safe_day_night,AVG(sport_cultural) As sport_cultural,
        AVG(nuisance_crime_hospitality) As nuisance_crime,AVG(group_interaction) As group_interaction,AVG(care_facilities) As care_facilities from main_data
        where region='west';
        
         """
dfwest = pd.read_sql(query, engine)
dfwest.round(2).style.set_properties(**{'background-color':'grey',
                                   'color':'Yellow',
                                   'boarder-color':'black',
                                   'boarder-width':'1px',
                                   'border-style':'solid'})
# Out:
# <style  type="text/css" >
#     #T_f3085b48_9ffd_11ea_a7ec_2c337a42c77arow0_col0 {
#             background-color:  grey;
#             color:  Yellow;
#             boarder-color:  black;
#             boarder-width:  1px;
#             border-style:  solid;
#         }    #T_f3085b48_9ffd_11ea_a7ec_2c337a42c77arow0_col1 {
#             background-color:  grey;
#             color:  Yellow;
#             boarder-color:  black;
#             boarder-width:  1px;
#             border-style:  solid;
#         }    #T_f3085b48_9ffd_11ea_a7ec_2c337a42c77arow0_col2 {
#             background-color:  grey;
#             color:  Yellow;
#             boarder-color:  black;
#             boarder-width:  1px;
#             border-style:  solid;
#         }    #T_f3085b48_9ffd_11ea_a7ec_2c337a42c77arow0_col3 {
#             background-color:  grey;
#             color:  Yellow;
#             boarder-color:  black;
#             boarder-width:  1px;
#             border-style:  solid;
# ...

# %%
query = """
        SELECT region As Region,AVG(avg_rent) AS Average_Rent,AVG(population_density) As population_density,AVG(parking) As Parking,AVG(entrepreneurs) As Enterpreneurs,AVG(safe_day_night) As safe_day_night,AVG(sport_cultural) As sport_cultural,
        AVG(nuisance_crime_hospitality) As nuisance_crime,AVG(group_interaction) As group_interaction,AVG(care_facilities) As care_facilities from main_data
        where region='noord';
        
         """
dfnoord = pd.read_sql(query, engine)
dfnoord.round(2).style.set_properties(**{'background-color':'grey',
                                   'color':'Yellow',
                                   'boarder-color':'black',
                                   'boarder-width':'1px',
                                   'border-style':'solid'})
# Out:
# <style  type="text/css" >
#     #T_f3cd9836_9ffd_11ea_90d8_2c337a42c77arow0_col0 {
#             background-color:  grey;
#             color:  Yellow;
#             boarder-color:  black;
#             boarder-width:  1px;
#             border-style:  solid;
#         }    #T_f3cd9836_9ffd_11ea_90d8_2c337a42c77arow0_col1 {
#             background-color:  grey;
#             color:  Yellow;
#             boarder-color:  black;
#             boarder-width:  1px;
#             border-style:  solid;
#         }    #T_f3cd9836_9ffd_11ea_90d8_2c337a42c77arow0_col2 {
#             background-color:  grey;
#             color:  Yellow;
#             boarder-color:  black;
#             boarder-width:  1px;
#             border-style:  solid;
#         }    #T_f3cd9836_9ffd_11ea_90d8_2c337a42c77arow0_col3 {
#             background-color:  grey;
#             color:  Yellow;
#             boarder-color:  black;
#             boarder-width:  1px;
#             border-style:  solid;
# ...

# %%
query = """
        SELECT region As Region,AVG(avg_rent) AS Average_Rent,AVG(population_density) As population_density,AVG(parking) As Parking,AVG(entrepreneurs) As Enterpreneurs,AVG(safe_day_night) As safe_day_night,AVG(sport_cultural) As sport_cultural,
        AVG(nuisance_crime_hospitality) As nuisance_crime,AVG(group_interaction) As group_interaction,AVG(care_facilities) As care_facilities from main_data
        where region='oost';
        
         """
dfoost = pd.read_sql(query, engine)
dfoost.round(2).style.set_properties(**{'background-color':'grey',
                                   'color':'Yellow',
                                   'boarder-color':'black',
                                   'boarder-width':'1px',
                                   'border-style':'solid'})
# Out:
# <style  type="text/css" >
#     #T_f42f28e2_9ffd_11ea_b41d_2c337a42c77arow0_col0 {
#             background-color:  grey;
#             color:  Yellow;
#             boarder-color:  black;
#             boarder-width:  1px;
#             border-style:  solid;
#         }    #T_f42f28e2_9ffd_11ea_b41d_2c337a42c77arow0_col1 {
#             background-color:  grey;
#             color:  Yellow;
#             boarder-color:  black;
#             boarder-width:  1px;
#             border-style:  solid;
#         }    #T_f42f28e2_9ffd_11ea_b41d_2c337a42c77arow0_col2 {
#             background-color:  grey;
#             color:  Yellow;
#             boarder-color:  black;
#             boarder-width:  1px;
#             border-style:  solid;
#         }    #T_f42f28e2_9ffd_11ea_b41d_2c337a42c77arow0_col3 {
#             background-color:  grey;
#             color:  Yellow;
#             boarder-color:  black;
#             boarder-width:  1px;
#             border-style:  solid;
# ...

# %%
query = """
        SELECT region As Region,AVG(avg_rent) AS Average_Rent,AVG(population_density) As population_density,AVG(parking) As Parking,AVG(entrepreneurs) As Enterpreneurs,AVG(safe_day_night) As safe_day_night,AVG(sport_cultural) As sport_cultural,
        AVG(nuisance_crime_hospitality) As nuisance_crime,AVG(group_interaction) As group_interaction,AVG(care_facilities) As care_facilities from main_data
        where region='zuid';
        
         """
dfzuid = pd.read_sql(query, engine)
dfzuid.round(2).style.set_properties(**{'background-color':'grey',
                                   'color':'Yellow',
                                   'boarder-color':'black',
                                   'boarder-width':'1px',
                                   'border-style':'solid'})
# Out:
# <style  type="text/css" >
#     #T_f490c91a_9ffd_11ea_a0bf_2c337a42c77arow0_col0 {
#             background-color:  grey;
#             color:  Yellow;
#             boarder-color:  black;
#             boarder-width:  1px;
#             border-style:  solid;
#         }    #T_f490c91a_9ffd_11ea_a0bf_2c337a42c77arow0_col1 {
#             background-color:  grey;
#             color:  Yellow;
#             boarder-color:  black;
#             boarder-width:  1px;
#             border-style:  solid;
#         }    #T_f490c91a_9ffd_11ea_a0bf_2c337a42c77arow0_col2 {
#             background-color:  grey;
#             color:  Yellow;
#             boarder-color:  black;
#             boarder-width:  1px;
#             border-style:  solid;
#         }    #T_f490c91a_9ffd_11ea_a0bf_2c337a42c77arow0_col3 {
#             background-color:  grey;
#             color:  Yellow;
#             boarder-color:  black;
#             boarder-width:  1px;
#             border-style:  solid;
# ...

# %%
query = """
        SELECT region As Region,AVG(avg_rent) AS Average_Rent,AVG(population_density) As population_density,AVG(parking) As Parking,AVG(entrepreneurs) As Enterpreneurs,AVG(safe_day_night) As safe_day_night,AVG(sport_cultural) As sport_cultural,
        AVG(nuisance_crime_hospitality) As nuisance_crime,AVG(group_interaction) As group_interaction,AVG(care_facilities) As care_facilities from main_data
        where region='zuidoost';
        
         """
dfzuidoost = pd.read_sql(query, engine)
dfzuidoost.round(2).style.set_properties(**{'background-color':'grey',
                                   'color':'Yellow',
                                   'boarder-color':'black',
                                   'boarder-width':'1px',
                                   'border-style':'solid'})
# Out:
# <style  type="text/css" >
#     #T_f51298e2_9ffd_11ea_b6df_2c337a42c77arow0_col0 {
#             background-color:  grey;
#             color:  Yellow;
#             boarder-color:  black;
#             boarder-width:  1px;
#             border-style:  solid;
#         }    #T_f51298e2_9ffd_11ea_b6df_2c337a42c77arow0_col1 {
#             background-color:  grey;
#             color:  Yellow;
#             boarder-color:  black;
#             boarder-width:  1px;
#             border-style:  solid;
#         }    #T_f51298e2_9ffd_11ea_b6df_2c337a42c77arow0_col2 {
#             background-color:  grey;
#             color:  Yellow;
#             boarder-color:  black;
#             boarder-width:  1px;
#             border-style:  solid;
#         }    #T_f51298e2_9ffd_11ea_b6df_2c337a42c77arow0_col3 {
#             background-color:  grey;
#             color:  Yellow;
#             boarder-color:  black;
#             boarder-width:  1px;
#             border-style:  solid;
# ...

# %%
query = """
        SELECT region As Region,AVG(avg_rent) AS Average_Rent,AVG(population_density) As population_density,AVG(parking) As Parking,AVG(entrepreneurs) As Enterpreneurs,AVG(safe_day_night) As safe_day_night,AVG(sport_cultural) As sport_cultural,
        AVG(nuisance_crime_hospitality) As nuisance_crime,AVG(group_interaction) As group_interaction,AVG(care_facilities) As care_facilities from main_data
        where region='n_west';
        
         """
dfnwest = pd.read_sql(query, engine)
dfnwest.round(2).style.set_properties(**{'background-color':'grey',
                                   'color':'Yellow',
                                   'boarder-color':'black',
                                   'boarder-width':'1px',
                                   'border-style':'solid'})
# Out:
# <style  type="text/css" >
#     #T_f57daec6_9ffd_11ea_ba5f_2c337a42c77arow0_col0 {
#             background-color:  grey;
#             color:  Yellow;
#             boarder-color:  black;
#             boarder-width:  1px;
#             border-style:  solid;
#         }    #T_f57daec6_9ffd_11ea_ba5f_2c337a42c77arow0_col1 {
#             background-color:  grey;
#             color:  Yellow;
#             boarder-color:  black;
#             boarder-width:  1px;
#             border-style:  solid;
#         }    #T_f57daec6_9ffd_11ea_ba5f_2c337a42c77arow0_col2 {
#             background-color:  grey;
#             color:  Yellow;
#             boarder-color:  black;
#             boarder-width:  1px;
#             border-style:  solid;
#         }    #T_f57daec6_9ffd_11ea_ba5f_2c337a42c77arow0_col3 {
#             background-color:  grey;
#             color:  Yellow;
#             boarder-color:  black;
#             boarder-width:  1px;
#             border-style:  solid;
# ...

# %%
 
result1 = dfwest.append(dfcentrum)
result2=result1.append(dfnoord)
result3=result2.append(dfzuid)
result4=result3.append(dfzuidoost)
result5=result4.append(dfoost)
finalData=result5.append(dfnwest)
finalData.set_index('Region',inplace=True)
finalData=finalData.round(2)
 
finalData.style.set_properties(**{'background-color':'grey',
                                   'color':'white',
                                   'boarder-color':'black',
                                   'boarder-width':'1px',
                                   'border-style':'solid'})
# Out:
# <style  type="text/css" >
#     #T_f5f3bb24_9ffd_11ea_aa3d_2c337a42c77arow0_col0 {
#             background-color:  grey;
#             color:  white;
#             boarder-color:  black;
#             boarder-width:  1px;
#             border-style:  solid;
#         }    #T_f5f3bb24_9ffd_11ea_aa3d_2c337a42c77arow0_col1 {
#             background-color:  grey;
#             color:  white;
#             boarder-color:  black;
#             boarder-width:  1px;
#             border-style:  solid;
#         }    #T_f5f3bb24_9ffd_11ea_aa3d_2c337a42c77arow0_col2 {
#             background-color:  grey;
#             color:  white;
#             boarder-color:  black;
#             boarder-width:  1px;
#             border-style:  solid;
#         }    #T_f5f3bb24_9ffd_11ea_aa3d_2c337a42c77arow0_col3 {
#             background-color:  grey;
#             color:  white;
#             boarder-color:  black;
#             boarder-width:  1px;
#             border-style:  solid;
# ...

# %%
GroupRanking=finalData.rank()
GroupRanking
# Out:
#           Average_Rent  population_density  Parking  Enterpreneurs  \
# Region
# west               4.0                 7.0      2.0            4.0
# centrum            6.0                 6.0      1.0            1.0
# noord              2.0                 1.0      4.0            5.0
# zuid               7.0                 5.0      6.0            2.0
# zuidoost           1.0                 2.0      5.0            7.0
# oost               5.0                 4.0      7.0            3.0
# n_west             3.0                 3.0      3.0            6.0
#
#           safe_day_night  sport_cultural  nuisance_crime  group_interaction  \
# Region
# west                 4.0             5.0             4.0                4.0
# centrum              6.0             7.0             1.0                5.0
# noord                3.0             1.0             3.0                2.0
# zuid                 7.0             6.0             7.0                7.0
# ...

# %%
def highlight_ranking(rank):     
    firstcriteria=rank==7 
   # print(['background-color:red' if i else '' for i in firstcriteria])
    return ['background-color:red' if i else '' for i in firstcriteria]

GroupRanking.style.apply(highlight_ranking)
# Out:
# <style  type="text/css" >
#     #T_f71fd9d4_9ffd_11ea_893c_2c337a42c77arow0_col1 {
#             background-color: red;
#         }    #T_f71fd9d4_9ffd_11ea_893c_2c337a42c77arow1_col5 {
#             background-color: red;
#         }    #T_f71fd9d4_9ffd_11ea_893c_2c337a42c77arow3_col0 {
#             background-color: red;
#         }    #T_f71fd9d4_9ffd_11ea_893c_2c337a42c77arow3_col4 {
#             background-color: red;
#         }    #T_f71fd9d4_9ffd_11ea_893c_2c337a42c77arow3_col6 {
#             background-color: red;
#         }    #T_f71fd9d4_9ffd_11ea_893c_2c337a42c77arow3_col7 {
#             background-color: red;
#         }    #T_f71fd9d4_9ffd_11ea_893c_2c337a42c77arow3_col8 {
#             background-color: red;
#         }    #T_f71fd9d4_9ffd_11ea_893c_2c337a42c77arow4_col3 {
#             background-color: red;
#         }    #T_f71fd9d4_9ffd_11ea_893c_2c337a42c77arow5_col2 {
#             background-color: red;
# ...

# %%
def maxColoring(rank):
    color='yellow' if rank < 4 else 'black'
    return f'background-color:{color}'


GroupRanking.style.applymap(maxColoring)
# Out:
# <style  type="text/css" >
#     #T_f790b908_9ffd_11ea_9e64_2c337a42c77arow0_col0 {
#             background-color: black;
#         }    #T_f790b908_9ffd_11ea_9e64_2c337a42c77arow0_col1 {
#             background-color: black;
#         }    #T_f790b908_9ffd_11ea_9e64_2c337a42c77arow0_col2 {
#             background-color: yellow;
#         }    #T_f790b908_9ffd_11ea_9e64_2c337a42c77arow0_col3 {
#             background-color: black;
#         }    #T_f790b908_9ffd_11ea_9e64_2c337a42c77arow0_col4 {
#             background-color: black;
#         }    #T_f790b908_9ffd_11ea_9e64_2c337a42c77arow0_col5 {
#             background-color: black;
#         }    #T_f790b908_9ffd_11ea_9e64_2c337a42c77arow0_col6 {
#             background-color: black;
#         }    #T_f790b908_9ffd_11ea_9e64_2c337a42c77arow0_col7 {
#             background-color: black;
#         }    #T_f790b908_9ffd_11ea_9e64_2c337a42c77arow0_col8 {
#             background-color: black;
# ...

# %%
Rank_District=finalData.groupby(['Region','population_density','population_density'])
Rank_District.hist()
# Out:
# Region    population_density  population_density
# centrum   13970.15            13970.15              [[AxesSubplot(0.125,0.670278;0.215278x0.209722...
# n_west    7294.10             7294.10               [[AxesSubplot(0.125,0.670278;0.215278x0.209722...
# noord     5410.88             5410.88               [[AxesSubplot(0.125,0.670278;0.215278x0.209722...
# oost      11296.55            11296.55              [[AxesSubplot(0.125,0.670278;0.215278x0.209722...
# west      19716.39            19716.39              [[AxesSubplot(0.125,0.670278;0.215278x0.209722...
# zuid      12763.30            12763.30              [[AxesSubplot(0.125,0.670278;0.215278x0.209722...
# zuidoost  5866.18             5866.18               [[AxesSubplot(0.125,0.670278;0.215278x0.209722...
# dtype: object

# %%
 
#Ranking and Maximum and Minimum 
def districtRanking():
    print("Select here:")
    print("Press 1. Avarage Rent *Press 2. Population Density ** 3. Parking Facilities \n")
    print("press 4. Sport and Cultural facilities ** Press 5. Nuisance crime   *Press 6.For Care Facilities  ")
    num=input("Which variable you want to see detail?")
    print("                           XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX                                  ")
    print("                          XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX                                  ")
    print("XXXXXXXXXXXXXXXXXXXXXXXX           GEMENTE AMSTERDAM             XXXXXXXXXXXXXXXXxxXXXXXXXX")
    print("XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX      Report             XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
    print(" ..........................XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX.................................")
    print("                           XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX                                  ")  
    if num=='1':
        print("__________________________****1. AVERAGE RENT****_________________________________\n")
        Rank_District=finalData.groupby(['Region','Average_Rent']).Average_Rent.agg(['mean']).round(2)
        Rank_District['Rank_Region']=Rank_District.rank(ascending=False,method='dense')
        print(Rank_District)
        num2=input("You See Max and see Min 1. Maximum 2. Minimum 3. Return to main menu")
        if num2=='1':
            print("Maximum Average Rent Districts:\n",Rank_District[Rank_District.Rank_Region<=3])
        elif num2=='2':
            print("Minimum Average Rent Districts:\n",Rank_District[Rank_District.Rank_Region>=5])
        else:
            print("Please Enter Your Choice Correctly")
    elif num=='2':
        print("___________________****2. Population Density****__________________________________\n")
        Rank_District=finalData.groupby(['Region','population_density']).Average_Rent.agg(['mean']).round(2)
        Rank_District['Rank_Region']=Rank_District.rank(ascending=False,method='dense')
        print(Rank_District)
        num2=input("You can See Max and see Min 1. Maximum 2. Minimum 3. Return to main menu")
        if num2=='1':
            print("Maximum Population Density:\n",Rank_District[Rank_District.Rank_Region<=3])
        elif num2=='2':
            print("Minimum Population Density:\n",Rank_District[Rank_District.Rank_Region>=5])
        else:
            print("Please Enter Your Choice Correctly")
    elif num=='3':
        print("___________________****3. Parking every Districts****______________________________\n")
        Rank_District=finalData.groupby(['Region','parking']).Average_Rent.agg(['mean']).round(2)
        Rank_District['Rank_Region']=Rank_District.rank(ascending=False,method='dense')
        print(Rank_District)
        num2=input("You can See Max and see Min 1. Maximum 2. Minimum 3. Return to main menu")
        if num2=='1':
            print("Maximum Parking Districts:\n",Rank_District[Rank_District.Rank_Region<=3])
        elif num2=='2':
            print("Minimum Sport and Cultural Facilities:\n",Rank_District[Rank_District.Rank_Region>=5])
        else:
            print("Please Enter Your Choice Correctly")   
    elif num=='4':
        print("_________________****4. Sport and Cultural Facilities ****____________________________\n")
        Rank_District=finalData.groupby(['Region','sport_cultural']).Average_Rent.agg(['mean']).round(2)
        Rank_District['Rank_Region']=Rank_District.rank(ascending=False,method='dense')
        print(Rank_District)
        num2=input("You can See Max and see Min 1. Maximum 2. Minimum 3. Return to main menu")
        if num2=='1':
            print("Maximum Sport and Cultural Facilities:\n",Rank_District[Rank_District.Region_Rent<=3])
        elif num2=='2':
            print("Minimum Sport and Cultural Facilities:\n",Rank_District[Rank_District.Rank_Region>=5])
        else:
            print("Please Enter Your Choice Correctly")       
    elif num=='5':
        print("_______________****5. Nuisance Crime and Nuisance Hospitality ****___________________________\n")
        Rank_District=finalData.groupby(['Region','nuisance_crime']).Average_Rent.agg(['mean']).round(2)
        Rank_District['Rank_Region']=Rank_District.rank(ascending=False,method='dense')
        print(Rank_District)
        num2=input("You can See Max and Min 1. Maximum 2. Minimum ")
        if num2=='1':
            print("Maximum Nuisance crime and Nuisance Hospitality:\n",Rank_District[Rank_District.Rank_Region<=3])
        elif num2=='2':
            print("Minimum Nuisance Crime and Nuisance Hospitality:\n",Rank_District[Rank_District.Rank_Region>=5])
        else:
            print("Please Enter Your Choice Correctly")    
    else: 
        print("_________________****6. Care Facilities ****____________________________\n")
        Rank_District=finalData.groupby(['Region','care_facilities']).Average_Rent.agg(['mean']).round(2)
        Rank_District['Rank_Region']=Rank_District.rank(ascending=False,method='dense')
        print(Rank_District)
        num2=input("You can See Max and see Min 1. Maximum 2. Minimum 3. Return to main menu")
        if num2=='1':
            print("Maximum care facilities:\n",Rank_District[Rank_District.Rank_Region<=3])
        elif num2=='2':
            print("Minimum care facilities:\n",Rank_District[Rank_District.Rank_Region>=5])
        else:
            print("Please Enter Your Choice Correctly")

# %%
print("...........................................................................................")
print("                          XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX                                  ")
print("XXXXXXXXXXXXXXXXXXXXXXXX           GEMENTE AMSTERDAM             XXXXXXXXXXXXXXXXxxXXXXXXXX")
print("XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX      Main Menu          XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
print(" ..........................XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX.................................")
print(" <<<<<<<<<<<<<<<<< 1.DISTRICTS >>>>>>>>>>>>>>>>>>>  2. SUB DISTRICTS >>>>>>>>>>>>>>>>>>>>>>>")
num1=input('')
if num1=='1':
    print(".............................WELCOME TO DISTRICTS OF AMSTERDAM..........................")
    districtRanking()
elif num1=='2':
    print(".............................WELCOME TO SUB DISTRICTS OF AMSTERDAM......................")
    rankingSubregion()
else:
    print("Sorry but you lost!! but we have something to show you")
# Out:
# ...........................................................................................
#                           XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# XXXXXXXXXXXXXXXXXXXXXXXX           GEMENTE AMSTERDAM             XXXXXXXXXXXXXXXXxxXXXXXXXX
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX      Main Menu          XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#  ..........................XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX.................................
#  <<<<<<<<<<<<<<<<< 1.DISTRICTS >>>>>>>>>>>>>>>>>>>  2. SUB DISTRICTS >>>>>>>>>>>>>>>>>>>>>>>
# 1
# .............................WELCOME TO DISTRICTS OF AMSTERDAM..........................
# Select here:
# Press 1. Avarage Rent *Press 2. Population Density ** 3. Parking Facilities
#
# press 4. Sport and Cultural facilities ** Press 5. Nuisance crime   *Press 6.For Care Facilities
# Which variable you want to see detail?2
#                            XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#                           XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# ...

# %%
Rank_District=AmsterData.groupby(['Population_Density','Average_Rent'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-0c8d9af6f542> in <module>
# ----> 1 Rank_District=AmsterData.groupby(['Population_Density','Average_Rent'])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed)
#    5808             group_keys=group_keys,
#    5809             squeeze=squeeze,
# -> 5810             observed=observed,
#    5811         )
#    5812
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated)
#     407                 sort=sort,
#     408                 observed=observed,
# --> 409                 mutated=self.mutated,
#     410             )
#     411
#
# ...
